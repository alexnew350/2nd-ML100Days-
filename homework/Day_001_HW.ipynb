# %% [markdown]
# 作業1：
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
# 工業4.0為近年產業中極力推廣的部分，其中機台預診維護的部分大量運用了領域知識及機械學習演算法與其中，
# 若能有效預測及診斷機台狀態，則能大幅提高機台生產效能
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 資料提供:ivanloginov (from kuggle)
# 資料名稱:The broken machine
# 該數據集是生產機器的數據。 大約有60種不同的指標，所有指標都沒有命名。 當然還有ytrain.csv文件中給出的機器故障數據。
# 因此，該數據集的主題是創建一個分類模型來預測故障。 並且，如果有需要，揭示具有最大影響的指標。
#
# 3. 蒐集而來的資料型態為何
# csv檔，陣列的結構
#
# 4. 這組資料想解決的問題如何評估
# x_train中為生產中會記錄下的指標數據，y_train為機台是否故障的判定，主要想解決的是透過生產過程中的數據，
# 能提早判別或預測出機台的狀態。
#
# 我們可使用分類或是分群的方式，來對機台狀態進行評估，並從中獲取在x_train中最有影響力的特徵。
#
#
# 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 1.乘客的國籍、年齡、搭乘時間
# 2.乘車的距離
# 3.乘車的汽車種類
# 4.收費標準與乘車班次的關係
#
# 假設
# 1.在國籍與搭乘時間及年齡部分，可鎖定不同時間的客戶族群，安排不同的司機，ex.外國旅客較多的時間點可安排外語能力較強的司機
# 2.觀察各地的乘車距離，安排某些候車地點
# 3.藉由汽車種類及數量進行有效安排
# 4.藉由收費與乘車班次的關係來獲取最大利潤
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 開發票的時間點
# 統計各班次
# 問卷調查核心問題中的各項題目
#
# 3. 蒐集而來的資料型態為何
# 格式可能會有許多種，
# 但盡量能轉換成csv檔以利統整
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 藉由各種假設及蒐集到的各項數據，來找出影響業績的前幾個最關鍵因子，
# 可利用統計的相關性或是其他資料探勘的演算法，透過關鍵因子的發現，
# 來改善及提高關鍵因子的分數，以提升業績。

# %%
#Mean Squared Error 的函式
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    """
        計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """    
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 207.780
# The Mean absolute error is 11.948
